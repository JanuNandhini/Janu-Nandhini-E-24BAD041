# %% [markdown]
# <a href="https://colab.research.google.com/github/JanuNandhini/Janu-Nandhini-E-24BAD041/blob/main/Hospital_Patient_Records.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Janu Nandhini E- 24BAD041
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/diabetes.csv")

print(df.head())
print(df.info())
print(df.isnull().sum())

df["Glucose"].plot(kind="hist", bins=20)
plt.xlabel("Glucose Level")
plt.title("Glucose Distribution")
plt.show()

df["Age"].plot(kind="hist", bins=20)
plt.xlabel("Age")
plt.title("Age Distribution")
plt.show()

df["Glucose"].plot(kind="box")
plt.title("Glucose Boxplot")
plt.show()

print("Average Glucose:", df["Glucose"].mean())
print("Average Age:", df["Age"].mean())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
